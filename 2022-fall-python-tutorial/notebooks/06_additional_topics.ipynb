# %% [markdown]
# # Additional Topics
#
# ## Common python functions
#
# This section will focus on functions that are used frequently in python - these range from data manipulation to completing exploratory data analysis. First up:
# - .head() - display the first n rows in a dataframe - by default it will be 5 records
# - .tail() - display the last n rows in a dataframe - by default it will be 5 records

# %%
# Load pandas package
import pandas as pd

# Define the file path
file_path = '../../2022-fall-python-tutorial/data/2022_boxscores.csv' # '../..' helps python to find the file

# Load file
df = pd.read_csv(file_path)

# %%
# Display the top 2 rows
df.head(2)
# Out:
#    away_assist_percentage  away_assists  away_block_percentage  away_blocks  \
# 0                    50.0            11                   15.4            6
# 1                    68.8            22                    0.0            0
#
#    away_defensive_rating  away_defensive_rebound_percentage  \
# 0                   98.6                               51.3
# 1                  101.3                               67.7
#
#    away_defensive_rebounds  away_effective_field_goal_percentage  \
# 0                       20                                 0.421
# 1                       21                                 0.507
#
#    away_field_goal_attempts  away_field_goal_percentage  ...  \
# 0                        57                       0.386  ...
# 1                        73                       0.438  ...
#
#    home_two_point_field_goals  home_win_percentage  home_wins  \
# 0                          17                  0.0          0
# 1                          15                  0.0          0
#
#                                        location        losing_abbr  \
# 0  Jon M. Huntsman Center, Salt Lake City, Utah  ABILENE-CHRISTIAN
# 1            Reed Arena, College Station, Texas  ABILENE-CHRISTIAN
#
#          losing_name  pace  winner  winning_abbr  winning_name
# 0  Abilene Christian  71.0    Home          UTAH          Utah
# 1  Abilene Christian  64.3    Home      TEXAS-AM     Texas A&M
#
# [2 rows x 86 columns]

# %%
# Display the last 3 rows of data
df.tail(3)
# Out:
#        away_assist_percentage  away_assists  away_block_percentage  \
# 11120                    28.0             7                    0.0
# 11121                    69.6            16                    6.3
# 11122                    42.9            12                   16.7
#
#        away_blocks  away_defensive_rating  away_defensive_rebound_percentage  \
# 11120            0                  115.1                               70.4
# 11121            2                  117.2                               59.3
# 11122            7                  101.4                               65.1
#
#        away_defensive_rebounds  away_effective_field_goal_percentage  \
# 11120                       19                                 0.500
# 11121                       16                                 0.529
# 11122                       28                                 0.577
#
#        away_field_goal_attempts  away_field_goal_percentage  ...  \
# 11120                        57                       0.439  ...
# 11121                        52                       0.442  ...
# 11122                        52                       0.538  ...
#
#        home_two_point_field_goals  home_win_percentage  home_wins  \
# 11120                          30                  0.0          0
# 11121                          17                  0.0          0
# 11122                          18                  0.0          0
#
#                                                 location       losing_abbr  \
# 11120               Ervin J. Nutter Center, Dayton, Ohio  YOUNGSTOWN-STATE
# 11121  Bank of Kentucky Center, Highland Heights, Ken...  YOUNGSTOWN-STATE
# 11122                   Beeghly Center, Youngstown, Ohio  YOUNGSTOWN-STATE
#
#             losing_name  pace  winner       winning_abbr       winning_name
# 11120  Youngstown State  72.5    Home       WRIGHT-STATE       Wright State
# 11121  Youngstown State  63.5    Home  NORTHERN-KENTUCKY  Northern Kentucky
# 11122  Youngstown State  72.2    Away      ROBERT-MORRIS      Robert Morris
#
# [3 rows x 86 columns]

# %% [markdown]
# To calculate general summary statistics on a dataframe we use **.describe()**. This will return the following values for each column:
# - count of records
# - mean
# - standard deviations
# - min
# - 25, 50, & 75 percentile value
# - max

# %%
# Calculate summary statistics on df
df.describe()
# Out:
#        away_assist_percentage  away_assists  away_block_percentage  \
# count            11123.000000  11123.000000           11123.000000
# mean                48.633678     11.850040               7.942803
# std                 13.574212      4.104921               5.458060
# min                  4.500000      1.000000               0.000000
# 25%                 39.100000      9.000000               3.600000
# 50%                 48.300000     12.000000               7.100000
# 75%                 58.300000     15.000000              11.100000
# max                 92.300000     31.000000              37.500000
#
#         away_blocks  away_defensive_rating  away_defensive_rebound_percentage  \
# count  11123.000000           11123.000000                       11123.000000
# mean       2.848422             104.750274                          72.546256
# std        2.004859              15.183268                           9.940378
# min        0.000000              42.600000                          21.700000
# 25%        1.000000              94.600000                          65.800000
# 50%        3.000000             104.500000                          73.100000
# 75%        4.000000             114.700000                          79.300000
# max       14.000000             169.300000                         100.000000
#
#        away_defensive_rebounds  away_effective_field_goal_percentage  \
# count             11123.000000                          11123.000000
# mean                 22.712218                              0.486718
# std                   4.837680                              0.087463
# min                   8.000000                              0.143000
# 25%                  19.000000                              0.427000
# 50%                  23.000000                              0.484000
# 75%                  26.000000                              0.545000
# max                  44.000000                              0.821000
#
#        away_field_goal_attempts  away_field_goal_percentage  ...  \
# count              11123.000000                11123.000000  ...
# mean                  57.497078                    0.424392  ...
# std                    6.926235                    0.073961  ...
# min                   29.000000                    0.143000  ...
# 25%                   53.000000                    0.375000  ...
# 50%                   57.000000                    0.423000  ...
# 75%                   62.000000                    0.475000  ...
# max                   96.000000                    0.692000  ...
#
#        home_total_rebounds  home_true_shooting_percentage  \
# count         11123.000000                   11123.000000
# mean             32.979052                       0.548731
# std               6.811988                       0.078797
# min              12.000000                       0.238000
# 25%              28.000000                       0.496000
# 50%              33.000000                       0.548000
# 75%              37.000000                       0.601000
# max              71.000000                       0.824000
#
#        home_turnover_percentage  home_turnovers  \
# count              11123.000000    11123.000000
# mean                  15.000917       11.688483
# std                    4.566044        3.745543
# min                    1.400000        1.000000
# 25%                   11.700000        9.000000
# 50%                   14.700000       11.000000
# 75%                   18.000000       14.000000
# max                   34.500000       28.000000
#
#        home_two_point_field_goal_attempts  \
# count                        11123.000000
# mean                            36.039108
# std                              7.253632
# min                             14.000000
# 25%                             31.000000
# 50%                             36.000000
# 75%                             41.000000
# max                             74.000000
#
#        home_two_point_field_goal_percentage  home_two_point_field_goals  \
# count                          11123.000000                11123.000000
# mean                               0.518032                   18.593275
# std                                0.097084                    4.855010
# min                                0.179000                    5.000000
# 25%                                0.452000                   15.000000
# 50%                                0.516000                   18.000000
# 75%                                0.581000                   22.000000
# max                                0.917000                   43.000000
#
#        home_win_percentage  home_wins          pace
# count              11123.0    11123.0  11123.000000
# mean                   0.0        0.0     69.302167
# std                    0.0        0.0      5.523341
# min                    0.0        0.0     51.500000
# 25%                    0.0        0.0     65.500000
# 50%                    0.0        0.0     69.000000
# 75%                    0.0        0.0     72.800000
# max                    0.0        0.0    107.800000
#
# [8 rows x 79 columns]

# %% [markdown]
# To get data types & non-null values, we use **.info()**

# %%
# Get dataframe data types & non-null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 86 columns):
# away_assist_percentage                    11123 non-null float64
# away_assists                              11123 non-null int64
# away_block_percentage                     11123 non-null float64
# away_blocks                               11123 non-null int64
# away_defensive_rating                     11123 non-null float64
# away_defensive_rebound_percentage         11123 non-null float64
# away_defensive_rebounds                   11123 non-null int64
# away_effective_field_goal_percentage      11123 non-null float64
# away_field_goal_attempts                  11123 non-null int64
# away_field_goal_percentage                11123 non-null float64
# away_field_goals                          11123 non-null int64
# away_free_throw_attempt_rate              11123 non-null float64
# away_free_throw_attempts                  11123 non-null int64
# away_free_throw_percentage                11114 non-null float64
# away_free_throws                          11123 non-null int64
# away_losses                               11123 non-null int64
# away_minutes_played                       11123 non-null int64
# away_offensive_rating                     11123 non-null float64
# away_offensive_rebound_percentage         11123 non-null float64
# away_offensive_rebounds                   11123 non-null int64
# away_personal_fouls                       11123 non-null int64
# away_points                               11123 non-null int64
# away_ranking                              636 non-null float64
# away_steal_percentage                     11123 non-null float64
# away_steals                               11123 non-null int64
# away_three_point_attempt_rate             11123 non-null float64
# away_three_point_field_goal_attempts      11123 non-null int64
# away_three_point_field_goal_percentage    11123 non-null float64
# away_three_point_field_goals              11123 non-null int64
# away_total_rebound_percentage             11123 non-null float64
# away_total_rebounds                       11123 non-null int64
# away_true_shooting_percentage             11123 non-null float64
# away_turnover_percentage                  11123 non-null float64
# away_turnovers                            11123 non-null int64
# away_two_point_field_goal_attempts        11123 non-null int64
# away_two_point_field_goal_percentage      11123 non-null float64
# away_two_point_field_goals                11123 non-null int64
# away_win_percentage                       11123 non-null float64
# away_wins                                 11123 non-null int64
# date                                      11123 non-null object
# home_assist_percentage                    11123 non-null float64
# home_assists                              11123 non-null int64
# home_block_percentage                     11123 non-null float64
# home_blocks                               11123 non-null int64
# home_defensive_rating                     11123 non-null float64
# home_defensive_rebound_percentage         11123 non-null float64
# home_defensive_rebounds                   11123 non-null int64
# home_effective_field_goal_percentage      11123 non-null float64
# home_field_goal_attempts                  11123 non-null int64
# home_field_goal_percentage                11123 non-null float64
# home_field_goals                          11123 non-null int64
# home_free_throw_attempt_rate              11123 non-null float64
# home_free_throw_attempts                  11123 non-null int64
# home_free_throw_percentage                11123 non-null float64
# home_free_throws                          11123 non-null int64
# home_losses                               11123 non-null int64
# home_minutes_played                       11123 non-null int64
# home_offensive_rating                     11123 non-null float64
# home_offensive_rebound_percentage         11123 non-null float64
# home_offensive_rebounds                   11123 non-null int64
# home_personal_fouls                       11123 non-null int64
# home_points                               11123 non-null int64
# home_ranking                              953 non-null float64
# home_steal_percentage                     11123 non-null float64
# home_steals                               11123 non-null int64
# home_three_point_attempt_rate             11123 non-null float64
# home_three_point_field_goal_attempts      11123 non-null int64
# home_three_point_field_goal_percentage    11123 non-null float64
# home_three_point_field_goals              11123 non-null int64
# home_total_rebound_percentage             11123 non-null float64
# home_total_rebounds                       11123 non-null int64
# home_true_shooting_percentage             11123 non-null float64
# home_turnover_percentage                  11123 non-null float64
# home_turnovers                            11123 non-null int64
# home_two_point_field_goal_attempts        11123 non-null int64
# home_two_point_field_goal_percentage      11123 non-null float64
# home_two_point_field_goals                11123 non-null int64
# home_win_percentage                       11123 non-null float64
# home_wins                                 11123 non-null int64
# location                                  10849 non-null object
# losing_abbr                               11123 non-null object
# losing_name                               11123 non-null object
# pace                                      11123 non-null float64
# winner                                    11123 non-null object
# winning_abbr                              11123 non-null object
# winning_name                              11123 non-null object
# dtypes: float64(39), int64(40), object(7)
# memory usage: 7.3+ MB

# %% [markdown]
# Calculate the count of each unique values for a given column: **.value_counts()**.

# %%
df['away_assists'].value_counts()
# Out:
# 12    1119
# 11    1053
# 10    1041
# 9      997
# 13     949
# 14     814
# 8      809
# 15     772
# 7      603
# 16     566
# 17     452
# 6      428
# 18     333
# 5      274
# 19     213
# 20     167
# 4      149
# 21      88
# 3       69
# 22      69
# 23      63
# 24      25
# 2       21
# 25      14
# 26      12
# 1        8
# 27       7
# 28       6
# 31       2
# Name: away_assists, dtype: int64

# %% [markdown]
# For a list of all column names in a dataframe use **.columns**

# %%
# Return list of column names
list(df.columns)
# Out:
# ['away_assist_percentage',
#  'away_assists',
#  'away_block_percentage',
#  'away_blocks',
#  'away_defensive_rating',
#  'away_defensive_rebound_percentage',
#  'away_defensive_rebounds',
#  'away_effective_field_goal_percentage',
#  'away_field_goal_attempts',
#  'away_field_goal_percentage',
#  'away_field_goals',
#  'away_free_throw_attempt_rate',
#  'away_free_throw_attempts',
#  'away_free_throw_percentage',
#  'away_free_throws',
#  'away_losses',
#  'away_minutes_played',
#  'away_offensive_rating',
#  'away_offensive_rebound_percentage',
#  'away_offensive_rebounds',
#  'away_personal_fouls',
#  'away_points',
#  'away_ranking',
#  'away_steal_percentage',
#  'away_steals',
#  'away_three_point_attempt_rate',
#  'away_three_point_field_goal_attempts',
#  'away_three_point_field_goal_percentage',
#  'away_three_point_field_goals',
#  'away_total_rebound_percentage',
#  'away_total_rebounds',
#  'away_true_shooting_percentage',
#  'away_turnover_percentage',
#  'away_turnovers',
#  'away_two_point_field_goal_attempts',
#  'away_two_point_field_goal_percentage',
#  'away_two_point_field_goals',
#  'away_win_percentage',
#  'away_wins',
#  'date',
#  'home_assist_percentage',
#  'home_assists',
#  'home_block_percentage',
#  'home_blocks',
#  'home_defensive_rating',
#  'home_defensive_rebound_percentage',
#  'home_defensive_rebounds',
#  'home_effective_field_goal_percentage',
#  'home_field_goal_attempts',
#  'home_field_goal_percentage',
#  'home_field_goals',
#  'home_free_throw_attempt_rate',
#  'home_free_throw_attempts',
#  'home_free_throw_percentage',
#  'home_free_throws',
#  'home_losses',
#  'home_minutes_played',
#  'home_offensive_rating',
#  'home_offensive_rebound_percentage',
#  'home_offensive_rebounds',
#  'home_personal_fouls',
#  'home_points',
#  'home_ranking',
#  'home_steal_percentage',
#  'home_steals',
#  'home_three_point_attempt_rate',
#  'home_three_point_field_goal_attempts',
#  'home_three_point_field_goal_percentage',
#  'home_three_point_field_goals',
#  'home_total_rebound_percentage',
#  'home_total_rebounds',
#  'home_true_shooting_percentage',
#  'home_turnover_percentage',
#  'home_turnovers',
#  'home_two_point_field_goal_attempts',
#  'home_two_point_field_goal_percentage',
#  'home_two_point_field_goals',
#  'home_win_percentage',
#  'home_wins',
#  'location',
#  'losing_abbr',
#  'losing_name',
#  'pace',
#  'winner',
#  'winning_abbr',
#  'winning_name']

# %% [markdown]
# Replace NA values with **.fillna()**

# %%
# Replace NA values with 0
df['away_assists'] = df['away_assists'].fillna(0)

# %% [markdown]
# ## Data Structure Manipulation
# - pivot
# - unpivot
# - other?
